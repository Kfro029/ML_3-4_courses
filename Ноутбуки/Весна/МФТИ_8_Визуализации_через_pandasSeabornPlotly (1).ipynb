# %% [markdown]
# #Визуализация данных

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# увеличим дефолтный размер графиков
from pylab import rcParams
rcParams['figure.figsize'] = 8,5

# %% [markdown]
# # <center> Matplotlib

# %% [markdown]
# Документация: https://matplotlib.org/contents.html

# %%
# первый позиционный аргумент – точки по Y, второй – точки по X. По умолчанию это единичные отрезки
plt.plot(5, 5, 'x');
# plt.show()

# %%
plt.plot([1, 4, 9, 12, 15, 20, 25])
plt.show()
plt.plot([25, 20, 15, 12, 9, 4, 2])
plt.show()

# %% [markdown]
# Поработаем с данными о продажах и оценках видеоигр с [Kaggle Datasets](https://www.kaggle.com/rush4ratio/video-game-sales-with-ratings).

# %%
df = pd.read_csv('https://raw.githubusercontent.com/obulygin/pyda_homeworks/master/stat_case_study/vgsales.csv')

# %%
print(df.shape)
# Out:
# (16719, 16)

# %%
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# 0          51.0          8       322.0  Nintendo      E
# 1           NaN        NaN         NaN       NaN    NaN
# 2          73.0        8.3       709.0  Nintendo      E
# 3          73.0          8       192.0  Nintendo      E
# 4           NaN        NaN         NaN       NaN    NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16717 non-null  object
#  1   Platform         16719 non-null  object
#  2   Year_of_Release  16450 non-null  float64
#  3   Genre            16717 non-null  object
#  4   Publisher        16665 non-null  object
#  5   NA_Sales         16719 non-null  float64
#  6   EU_Sales         16719 non-null  float64
#  7   JP_Sales         16719 non-null  float64
#  8   Other_Sales      16719 non-null  float64
#  9   Global_Sales     16719 non-null  float64
#  10  Critic_Score     8137 non-null   float64
#  11  Critic_Count     8137 non-null   float64
#  12  User_Score       10015 non-null  object
#  13  User_Count       7590 non-null   float64
#  14  Developer        10096 non-null  object
#  15  Rating           9950 non-null   object
# dtypes: float64(9), object(7)
# memory usage: 2.0+ MB

# %%
# почему в User_Score object?

# %% [markdown]
#  TBD, to be determined

# %%
df['User_Score'] = df['User_Score'].replace('tbd', np.NaN)
df['User_Score'].unique()
# Out:
# array(['8', nan, '8.3', '8.5', '6.6', '8.4', '8.6', '7.7', '6.3', '7.4',
#        '8.2', '9', '7.9', '8.1', '8.7', '7.1', '3.4', '5.3', '4.8', '3.2',
#        '8.9', '6.4', '7.8', '7.5', '2.6', '7.2', '9.2', '7', '7.3', '4.3',
#        '7.6', '5.7', '5', '9.1', '6.5', '8.8', '6.9', '9.4', '6.8', '6.1',
#        '6.7', '5.4', '4', '4.9', '4.5', '9.3', '6.2', '4.2', '6', '3.7',
#        '4.1', '5.8', '5.6', '5.5', '4.4', '4.6', '5.9', '3.9', '3.1',
#        '2.9', '5.2', '3.3', '4.7', '5.1', '3.5', '2.5', '1.9', '3', '2.7',
#        '2.2', '2', '9.5', '2.1', '3.6', '2.8', '1.8', '3.8', '0', '1.6',
#        '9.6', '2.4', '1.7', '1.1', '0.3', '1.5', '0.7', '1.2', '2.3',
#        '0.5', '1.3', '0.2', '0.6', '1.4', '0.9', '1', '9.7'], dtype=object)

# %%
# исправим типы данных
df['Year_of_Release'] = df['Year_of_Release'].astype('Int64')
df['User_Count'] = df['User_Count'].astype('Int64')
df['User_Score'] = df['User_Score'].astype('float64')
df['Critic_Count'] = df['Critic_Count'].astype('Int64')

# переводим оценки в один формат
df['User_Score'] = df['User_Score'] * 10

# %% [markdown]
# ## График
# Построим график динамики продаж видеоигр

# %%
dynamics_by_region = df[['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales', 'Year_of_Release']] \
                     .groupby('Year_of_Release').sum()
dynamics_by_region
# Out:
#                  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Year_of_Release
# 1980                10.59      0.67      0.00         0.12         11.38
# 1981                33.40      1.96      0.00         0.32         35.77
# 1982                26.92      1.65      0.00         0.31         28.86
# 1983                 7.76      0.80      8.10         0.14         16.79
# 1984                33.28      2.10     14.27         0.70         50.36
# 1985                33.73      4.74     14.56         0.92         53.94
# 1986                12.50      2.84     19.81         1.93         37.07
# 1987                 8.46      1.41     11.63         0.20         21.74
# 1988                23.87      6.59     15.76         0.99         47.22
# 1989                45.15      8.44     18.36         1.50         73.45
# 1990                25.46      7.63     14.88         1.40         49.39
# 1991                12.76      3.95     14.78         0.74         32.23
# 1992                33.89     11.71     28.91         1.65         76.17
# 1993                16.90      5.18     25.36         0.97         48.40
# 1994                28.16     14.88     33.99         2.20         79.18
# 1995                24.83     14.90     45.75         2.64         88.11
# 1996                86.76     47.26     57.44         7.69        199.15
# 1997                94.75     48.32     48.87         9.13        200.98
# 1998               128.36     66.90     50.04        11.01        256.45
# 1999               126.06     62.67     52.34        10.04        251.25
# 2000                94.50     52.77     42.77        11.62        201.58
# 2001               173.98     94.89     39.86        22.73        331.47
# 2002               216.19    109.75     41.76        27.27        395.51
# 2003               193.61    103.81     34.20        25.92        357.80
# 2004               222.51    107.28     41.65        47.24        419.05
# 2005               242.15    121.11     54.27        40.29        458.31
# 2006               262.13    127.89     73.74        53.95        518.22
# 2007               309.89    157.82     60.29        76.75        605.37
# 2008               348.69    181.14     60.25        81.42        671.79
# 2009               335.55    187.94     61.89        73.44        658.88
# 2010               300.65    171.42     59.49        58.57        590.59
# 2011               238.79    162.97     53.07        52.75        507.79
# 2012               153.26    114.59     51.80        36.19        355.84
# 2013               153.65    121.55     47.69        38.35        361.24
# 2014               132.27    122.74     39.69        36.83        331.51
# 2015               106.86     96.72     34.09        30.31        268.05
# 2016                44.93     51.22     19.31        14.48        130.10
# 2017                 0.00      0.00      0.06         0.00          0.06
# 2020                 0.27      0.00      0.00         0.02          0.29

# %%
# применяем функцию plot из matplotlib
# для каждой дополнительной настройки есть своя функция
plt.plot(dynamics_by_region.index, dynamics_by_region['Global_Sales'])
plt.title('Динамика продаж видеоигр')
plt.xlabel('Год')
plt.ylabel('Продажи, млн.');

# %%
# можем использовать цикл, чтобы построить графики для каждого региона
for region in dynamics_by_region.columns:
    plt.plot(dynamics_by_region.index, dynamics_by_region[region])

plt.title('Динамика продаж видеоигр')
plt.xlabel('Год')
plt.ylabel('Продажи, млн.')
plt.legend(dynamics_by_region);

# %% [markdown]
# # Визуализации через pandas

# %% [markdown]
# Метод .plot() в pandas основан на matplotlib. Если мы работаем с датафреймами, то это, как правило, более удобный вариант, чем использование matplotlib самой по себе. Мы сконцентрируемся на этом варианте.
#
# Документация: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.html

# %%
# если работает с табличными структурами, то можем воспользоваться функционалом,
# встроенным в pandas. Так удобнее
# Метод plot по-умолчанию использует индекс датафрейма для оси X
# метод plot по-умолчанию строит график
dynamics_by_region['Global_Sales'].plot(title='Динамика продаж видеоигр',
                                        xlabel='Год',
                                        ylabel='Продажи, млн.');

# %%
# plot без цикла построит графики для каждого региона (столбца)
# если у plot нету нужных методов, то можно применить функции matplotlib
dynamics_by_region.plot(title='Динамика продаж видеоигр',
                        xlabel='Год',
                        ylabel='Продажи, млн.')
plt.text(2007, 680, 'Почему отсюда начался спад?')

plt.legend(loc='upper left');

# %% [markdown]
# ## Area chart

# %%
# по-умолчанию  Area chart всегда накопительный
dynamics_by_region.drop('Global_Sales', axis=1).plot(kind='area',
                                                     title='Динамика продаж видеоигр',
                                                     xlabel='Год',
                                                     stacked=False,
                                                     ylabel='Продажи, млн.');

# %% [markdown]
# ## Гистограммы

# %%
# распределение оценок пользователей
df['User_Score'].plot(kind='hist',
                      title='Распределение оценок пользователей',
                      bins=20);

# %%
# распределение оценок критиков
df['Critic_Score'].plot(kind='hist',
                        title='Распределение оценок критиков',
                        bins=20);

# %%
# сравнение
df['Critic_Score'].plot(kind='hist',
                        alpha=0.5,
                        bins=20,
                        density=False)


df['User_Score'].plot(kind='hist',
                      alpha=0.5,
                      bins=20,
                      density=False)

plt.legend(loc='upper left')
plt.title('Сравнение распределений оценок видеоигр');

# %% [markdown]
# ## Столбчатая диаграмма

# %%
# количество игр в разрезе платформ
games_by_platforms = df[['Name', 'Platform']].groupby('Platform').count()
games_by_platforms.sort_values('Name')
# Out:
#           Name
# Platform
# GG           1
# PCFX         1
# TG16         2
# 3DO          3
# WS           6
# SCD          6
# NG          12
# GEN         27
# DC          52
# GB          98
# NES         98
# 2600       133
# WiiU       147
# SAT        173
# SNES       239
# XOne       247
# N64        319
# PS4        393
# PSV        432
# 3DS        520
# GC         556
# GBA        822
# XB         824
# PC         974
# PS        1197
# PSP       1209
# X360      1262
# Wii       1320
# PS3       1331
# DS        2152
# PS2       2161

# %% [markdown]
# ### 🧠 Упражнение: построить столбчатую диаграмму
#
# Для 'PC', 'X360', 'PS3', 'PS4', 'XOne'
#
# 1. Добавить заголовок: 'Топ 5 платформ по количеству и игр'
# 2. Добавить наименования осей: 'Платформа', 'Количество игр'

# %%
#@title Решение
games_by_platforms.loc[['PC', 'X360', 'PS3', 'PS4', 'XOne']].plot(kind='bar',
                                                                  title='Топ 5 платформ по количеству и игр',
                                                                  xlabel='Платформа',
                                                                  ylabel='Количество игр');

# %%
top5_genres = df[['Global_Sales', 'Genre']].groupby('Genre').sum().sort_values('Global_Sales', ascending=False).head(5)
top5_genres
# Out:
#               Global_Sales
# Genre
# Action             1745.27
# Sports             1332.00
# Shooter            1052.94
# Role-Playing        934.40
# Platform            828.08

# %%
# топ-5 жанров по продажам
top5_genres.plot(kind='bar',
                 title='Топ 5 жанров по продажам',
                 xlabel='Платформа',
                 ylabel='Количество игр')

for i, val in enumerate(top5_genres.values):
    plt.text(i, val, int(val), horizontalalignment='center', verticalalignment='bottom', fontdict={'size':14})
# Out:
# <ipython-input-38-872f12f4b8bb>:8: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   plt.text(i, val, int(val), horizontalalignment='center', verticalalignment='bottom', fontdict={'size':14})

# %%
# динамика продаж в разрезе регионов. Выглядит фигово
dynamics_by_region.plot(kind='bar');

# %%
# Сделаем с накоплением!
dynamics_by_region.drop('Global_Sales', axis=1).plot(kind='bar', stacked=True);

# %% [markdown]
# ## Круговая диаграмма

# %%
pie_data = df['Platform'].value_counts()
pie_data
# Out:
# Platform
# PS2     2161
# DS      2152
# PS3     1331
# Wii     1320
# X360    1262
# PSP     1209
# PS      1197
# PC       974
# XB       824
# GBA      822
# GC       556
# 3DS      520
# PSV      432
# PS4      393
# N64      319
# XOne     247
# SNES     239
# SAT      173
# WiiU     147
# 2600     133
# NES       98
# GB        98
# DC        52
# GEN       29
# NG        12
# SCD        6
# WS         6
# 3DO        3
# TG16       2
# GG         1
# PCFX       1
# Name: count, dtype: int64

# %%
# количество игр по платформам
pie_data.plot(kind='pie',
              title='Количество игр по платформам');

# %%
# количество игр по платформам (берем только топ-5)
top_platforms = df['Platform'].value_counts().head(5)
top_platforms.plot(kind='pie')
plt.legend(bbox_to_anchor=(0.9, 0.5, 0.5, 0.5));

# %% [markdown]
# ## Boxplot

# %%
# очень хорошо подходит для поиска выбросов!
df['User_Score'].plot(kind='box',
                      title='Распределение оценок пользователей',
                      grid=True);

# %% [markdown]
# ### 🧠 Упражнение: построить ящик с усами
#
# Два ящика для 'User_Score', 'Critic_Score'

# %%
#@title Решение

df[['User_Score', 'Critic_Score']].plot(kind='box',
                                        title='Распределение оценок',
                                        grid=True);

# %% [markdown]
# ## Точечная диаграмма

# %%
# посмотрим на взаимосвязь оценок и продаж
df.plot(kind='scatter',
        x='User_Score',
        y='Global_Sales',
        title='Корреляция между продажами и оценками пользователей')
plt.ylim(0, 40)

df.plot(kind='scatter',
        x='Critic_Score',
        y='Global_Sales',
        title='Корреляция между продажами и оценками критиков')
plt.ylim(0, 40);

# %%
# добавим третью ось
df.plot(kind='scatter',
        x='User_Score',
        y='Critic_Score',
        s=df['Global_Sales']*20,
        title='Корреляция между оценкой критиков, пользоваталей и продажами'
       );

# %% [markdown]
# ## Стилизация таблиц

# %%
# выведем информацию о топ-10 издателях по продажам
top_developers_df = df.groupby('Developer')[['Global_Sales']].sum()\
                          .sort_values('Global_Sales', ascending=False).head(10)

top_developers_df
# Out:
#                    Global_Sales
# Developer
# Nintendo                 531.71
# EA Sports                175.38
# EA Canada                142.32
# Ubisoft                  132.54
# Rockstar North           119.47
# Capcom                   115.71
# Ubisoft Montreal         108.31
# Treyarch                 103.16
# EA Tiburon                96.12
# Traveller's Tales         79.22

# %%
top_developers_df.style.bar(align='mid')
# Out:
# <style type="text/css">
# #T_d041d_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_d041d_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 33.0%, transparent 33.0%);
# }
# #T_d041d_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 26.8%, transparent 26.8%);
# }
# #T_d041d_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 24.9%, transparent 24.9%);
# }
# #T_d041d_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 22.5%, transparent 22.5%);
# }
# #T_d041d_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 21.8%, transparent 21.8%);
# }
# #T_d041d_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 20.4%, transparent 20.4%);
# }
# #T_d041d_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 19.4%, transparent 19.4%);
# }
# #T_d041d_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 18.1%, transparent 18.1%);
# }
# #T_d041d_row9_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 14.9%, transparent 14.9%);
# }
# </style>
# <table id="T_d041d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d041d_level0_col0" class="col_heading level0 col0" >Global_Sales</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Developer</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d041d_level0_row0" class="row_heading level0 row0" >Nintendo</th>
#       <td id="T_d041d_row0_col0" class="data row0 col0" >531.710000</td>
#     </tr>
#     <tr>
#       <th id="T_d041d_level0_row1" class="row_heading level0 row1" >EA Sports</th>
#       <td id="T_d041d_row1_col0" class="data row1 col0" >175.380000</td>
#     </tr>
#     <tr>
#       <th id="T_d041d_level0_row2" class="row_heading level0 row2" >EA Canada</th>
#       <td id="T_d041d_row2_col0" class="data row2 col0" >142.320000</td>
#     </tr>
#     <tr>
#       <th id="T_d041d_level0_row3" class="row_heading level0 row3" >Ubisoft</th>
#       <td id="T_d041d_row3_col0" class="data row3 col0" >132.540000</td>
#     </tr>
#     <tr>
#       <th id="T_d041d_level0_row4" class="row_heading level0 row4" >Rockstar North</th>
#       <td id="T_d041d_row4_col0" class="data row4 col0" >119.470000</td>
#     </tr>
#     <tr>
#       <th id="T_d041d_level0_row5" class="row_heading level0 row5" >Capcom</th>
#       <td id="T_d041d_row5_col0" class="data row5 col0" >115.710000</td>
#     </tr>
#     <tr>
#       <th id="T_d041d_level0_row6" class="row_heading level0 row6" >Ubisoft Montreal</th>
#       <td id="T_d041d_row6_col0" class="data row6 col0" >108.310000</td>
#     </tr>
#     <tr>
#       <th id="T_d041d_level0_row7" class="row_heading level0 row7" >Treyarch</th>
#       <td id="T_d041d_row7_col0" class="data row7 col0" >103.160000</td>
#     </tr>
#     <tr>
#       <th id="T_d041d_level0_row8" class="row_heading level0 row8" >EA Tiburon</th>
#       <td id="T_d041d_row8_col0" class="data row8 col0" >96.120000</td>
#     </tr>
#     <tr>
#       <th id="T_d041d_level0_row9" class="row_heading level0 row9" >Traveller's Tales</th>
#       <td id="T_d041d_row9_col0" class="data row9 col0" >79.220000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # <center> Seaborn

# %%
import seaborn as sns

# %% [markdown]
# C помощью `seaborn` можно построить достаточно сложные визуализации, которые были бы очень сложны для представления в коде при использовании `matplotlib`. Рассмотрим часть из них.

# %% [markdown]
# Посмотрим на **распределение оценок критиков `Critic_Score`**. Для этого построим __`histplot`__.

# %%
sns.histplot(df['Critic_Score'])
plt.title('Распределение оценок критиков');

# %% [markdown]
# Для того чтобы подробнее посмотреть на взаимосвязь двух численных признаков можно использовать __`joint_plot`__ – это гибрид `scatter plot` и `histogram`. Посмотрим на то, как связаны между собой **оценка критиков `Critic_Score` и оценка пользователя `User_Score`**.

# %%
sns.jointplot(x='Critic_Score', y='User_Score', data=df, kind='reg');

# %%
sns.jointplot(x='Critic_Score', y='User_Score', data=df, kind='reg',
              marginal_kws=dict(bins=10, fill=False));

# %% [markdown]
# **pair plot (scatter plot matrix)** поможет нам посмотреть на одной картинке, как связаны между собой различные признаки в наборе данных

# %%
# sns.pairplot(df);

# %%
sns.pairplot(df[['Global_Sales', 'Critic_Score', 'User_Score']]);

# %% [markdown]
# Давайте **сравним оценки критиков игр для топ-10 крупнейших игровых платформ** при помощи `boxplot`.

# %%
top_platforms = df['Platform'].value_counts().sort_values(ascending=False).head(10).index.values
top_platforms
# Out:
# array(['PS2', 'DS', 'PS3', 'Wii', 'X360', 'PSP', 'PS', 'PC', 'XB', 'GBA'],
#       dtype=object)

# %%
sns.boxplot(x="Platform", y="Critic_Score",
            data=df[df['Platform'].isin(top_platforms)]);

# %% [markdown]
# `Heat map` позволяет посмотреть на распределение какого-то численного признака по двум категориальным. Визуализируем **суммарные продажи игр по жанрам и игровым платформам**.

# %%
platform_genre_sales = df[df['Platform'].isin(top_platforms)].pivot_table(
                                  index='Platform',
                                  columns='Genre',
                                  values='Global_Sales',
                                  aggfunc=sum).fillna(0)

platform_genre_sales
# Out:
# Genre     Action  Adventure  Fighting    Misc  Platform  Puzzle  Racing  \
# Platform
# DS        112.70      45.90      7.11  135.72     75.92   82.72   38.10
# GBA        55.76      14.68      4.21   36.25     78.30   12.92   18.80
# PC         31.71      10.04      0.29    8.57      0.49    0.92    3.99
# PS        127.05      20.97     72.68   44.90     64.21   12.08  103.19
# PS2       272.76      21.16     92.60  101.14     72.51    5.90  156.28
# PS3       301.55      22.28     51.08   46.88     29.71    0.58   72.13
# PSP        64.11      10.68     21.82   13.91     17.09    5.52   34.29
# Wii       114.51      17.83     23.36  216.37     88.92   15.37   60.25
# X360      239.69      14.94     37.34   91.54     11.32    0.85   65.00
# XB         49.28       3.06     13.55    9.58      9.66    0.42   31.49
#
# Genre     Role-Playing  Shooter  Simulation  Sports  Strategy
# Platform
# DS              124.44     7.92      130.29   31.41     14.87
# GBA              64.21     3.60        5.91   16.41      7.45
# PC               47.72    45.92       52.61   12.01     46.03
# PS               78.30    39.31       25.33  120.97     21.69
# PS2              93.50   108.57       42.66  273.41     15.15
# PS3              73.67   192.46       10.39  133.88      4.82
# PSP              48.98    19.66        6.23   41.51     10.50
# Wii              13.70    28.15       36.03  288.61      5.03
# X360             71.31   276.98       14.18  138.45     10.03
# XB               13.51    63.55        7.11   54.27      2.78

# %%
sns.heatmap(platform_genre_sales, cmap='PuBu', annot=True, fmt='.1f');

# %%
platform_genre_sales.style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_e8a33_row0_col0 {
#   background-color: #b8e3b2;
#   color: #000000;
# }
# #T_e8a33_row0_col1, #T_e8a33_row0_col5, #T_e8a33_row0_col7, #T_e8a33_row0_col9, #T_e8a33_row2_col11, #T_e8a33_row4_col2, #T_e8a33_row4_col6, #T_e8a33_row5_col0, #T_e8a33_row7_col3, #T_e8a33_row7_col4, #T_e8a33_row7_col10, #T_e8a33_row8_col8 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_e8a33_row0_col2 {
#   background-color: #edf8e9;
#   color: #000000;
# }
# #T_e8a33_row0_col3 {
#   background-color: #46ae60;
#   color: #f1f1f1;
# }
# #T_e8a33_row0_col4 {
#   background-color: #067230;
#   color: #f1f1f1;
# }
# #T_e8a33_row0_col6 {
#   background-color: #cdecc7;
#   color: #000000;
# }
# #T_e8a33_row0_col8, #T_e8a33_row1_col10 {
#   background-color: #f5fbf2;
#   color: #000000;
# }
# #T_e8a33_row0_col10, #T_e8a33_row4_col5, #T_e8a33_row8_col9 {
#   background-color: #edf8ea;
#   color: #000000;
# }
# #T_e8a33_row0_col11 {
#   background-color: #bee5b8;
#   color: #000000;
# }
# #T_e8a33_row1_col0, #T_e8a33_row7_col8 {
#   background-color: #ebf7e7;
#   color: #000000;
# }
# #T_e8a33_row1_col1 {
#   background-color: #c1e6ba;
#   color: #000000;
# }
# #T_e8a33_row1_col2 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_e8a33_row1_col3 {
#   background-color: #e3f4de;
#   color: #000000;
# }
# #T_e8a33_row1_col4 {
#   background-color: #006b2b;
#   color: #f1f1f1;
# }
# #T_e8a33_row1_col5 {
#   background-color: #dff3da;
#   color: #000000;
# }
# #T_e8a33_row1_col6 {
#   background-color: #e9f7e5;
#   color: #000000;
# }
# #T_e8a33_row1_col7, #T_e8a33_row8_col10 {
#   background-color: #83cb82;
#   color: #000000;
# }
# #T_e8a33_row1_col8, #T_e8a33_row1_col9, #T_e8a33_row2_col0, #T_e8a33_row2_col2, #T_e8a33_row2_col3, #T_e8a33_row2_col4, #T_e8a33_row2_col6, #T_e8a33_row2_col10, #T_e8a33_row5_col5, #T_e8a33_row6_col9, #T_e8a33_row7_col7, #T_e8a33_row9_col1, #T_e8a33_row9_col5, #T_e8a33_row9_col7, #T_e8a33_row9_col11 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_e8a33_row1_col11, #T_e8a33_row6_col10 {
#   background-color: #e8f6e3;
#   color: #000000;
# }
# #T_e8a33_row2_col1 {
#   background-color: #dcf2d7;
#   color: #000000;
# }
# #T_e8a33_row2_col5, #T_e8a33_row8_col5, #T_e8a33_row9_col3, #T_e8a33_row9_col9 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_e8a33_row2_col7, #T_e8a33_row7_col0 {
#   background-color: #b6e2af;
#   color: #000000;
# }
# #T_e8a33_row2_col8, #T_e8a33_row3_col9, #T_e8a33_row9_col10 {
#   background-color: #def2d9;
#   color: #000000;
# }
# #T_e8a33_row2_col9 {
#   background-color: #a0d99b;
#   color: #000000;
# }
# #T_e8a33_row3_col0 {
#   background-color: #a8dca2;
#   color: #000000;
# }
# #T_e8a33_row3_col1 {
#   background-color: #91d28e;
#   color: #000000;
# }
# #T_e8a33_row3_col2 {
#   background-color: #19833e;
#   color: #f1f1f1;
# }
# #T_e8a33_row3_col3 {
#   background-color: #daf0d4;
#   color: #000000;
# }
# #T_e8a33_row3_col4, #T_e8a33_row4_col7 {
#   background-color: #2a924a;
#   color: #f1f1f1;
# }
# #T_e8a33_row3_col5, #T_e8a33_row9_col2 {
#   background-color: #e1f3dc;
#   color: #000000;
# }
# #T_e8a33_row3_col6 {
#   background-color: #3ba458;
#   color: #f1f1f1;
# }
# #T_e8a33_row3_col7 {
#   background-color: #52b365;
#   color: #f1f1f1;
# }
# #T_e8a33_row3_col8 {
#   background-color: #e4f5df;
#   color: #000000;
# }
# #T_e8a33_row3_col10 {
#   background-color: #9bd696;
#   color: #000000;
# }
# #T_e8a33_row3_col11 {
#   background-color: #8bcf89;
#   color: #000000;
# }
# #T_e8a33_row4_col0 {
#   background-color: #006729;
#   color: #f1f1f1;
# }
# #T_e8a33_row4_col1 {
#   background-color: #90d18d;
#   color: #000000;
# }
# #T_e8a33_row4_col3, #T_e8a33_row5_col1, #T_e8a33_row5_col6 {
#   background-color: #87cd86;
#   color: #000000;
# }
# #T_e8a33_row4_col4 {
#   background-color: #117b38;
#   color: #f1f1f1;
# }
# #T_e8a33_row4_col8 {
#   background-color: #9ed798;
#   color: #000000;
# }
# #T_e8a33_row4_col9 {
#   background-color: #bae3b3;
#   color: #000000;
# }
# #T_e8a33_row4_col10 {
#   background-color: #005622;
#   color: #f1f1f1;
# }
# #T_e8a33_row4_col11 {
#   background-color: #bce4b5;
#   color: #000000;
# }
# #T_e8a33_row5_col2 {
#   background-color: #60ba6c;
#   color: #f1f1f1;
# }
# #T_e8a33_row5_col3 {
#   background-color: #d7efd1;
#   color: #000000;
# }
# #T_e8a33_row5_col4 {
#   background-color: #afdfa8;
#   color: #000000;
# }
# #T_e8a33_row5_col7 {
#   background-color: #63bc6e;
#   color: #f1f1f1;
# }
# #T_e8a33_row5_col8 {
#   background-color: #319a50;
#   color: #f1f1f1;
# }
# #T_e8a33_row5_col9 {
#   background-color: #f2faef;
#   color: #000000;
# }
# #T_e8a33_row5_col10 {
#   background-color: #8ace88;
#   color: #000000;
# }
# #T_e8a33_row5_col11 {
#   background-color: #f0f9ed;
#   color: #000000;
# }
# #T_e8a33_row6_col0 {
#   background-color: #e6f5e1;
#   color: #000000;
# }
# #T_e8a33_row6_col1, #T_e8a33_row6_col11 {
#   background-color: #d9f0d3;
#   color: #000000;
# }
# #T_e8a33_row6_col2 {
#   background-color: #cbebc5;
#   color: #000000;
# }
# #T_e8a33_row6_col3 {
#   background-color: #f4fbf1;
#   color: #000000;
# }
# #T_e8a33_row6_col4 {
#   background-color: #d6efd0;
#   color: #000000;
# }
# #T_e8a33_row6_col5, #T_e8a33_row6_col8 {
#   background-color: #eff9eb;
#   color: #000000;
# }
# #T_e8a33_row6_col6 {
#   background-color: #d4eece;
#   color: #000000;
# }
# #T_e8a33_row6_col7 {
#   background-color: #b2e0ac;
#   color: #000000;
# }
# #T_e8a33_row7_col1 {
#   background-color: #aadda4;
#   color: #000000;
# }
# #T_e8a33_row7_col2 {
#   background-color: #c8e9c1;
#   color: #000000;
# }
# #T_e8a33_row7_col5, #T_e8a33_row9_col6 {
#   background-color: #d8f0d2;
#   color: #000000;
# }
# #T_e8a33_row7_col6 {
#   background-color: #a3da9d;
#   color: #000000;
# }
# #T_e8a33_row7_col9 {
#   background-color: #caeac3;
#   color: #000000;
# }
# #T_e8a33_row7_col11 {
#   background-color: #f0f9ec;
#   color: #000000;
# }
# #T_e8a33_row8_col0 {
#   background-color: #1d8640;
#   color: #f1f1f1;
# }
# #T_e8a33_row8_col1 {
#   background-color: #c0e6b9;
#   color: #000000;
# }
# #T_e8a33_row8_col2, #T_e8a33_row8_col3, #T_e8a33_row8_col6 {
#   background-color: #98d594;
#   color: #000000;
# }
# #T_e8a33_row8_col4 {
#   background-color: #e5f5e1;
#   color: #000000;
# }
# #T_e8a33_row8_col7 {
#   background-color: #6bc072;
#   color: #000000;
# }
# #T_e8a33_row8_col11 {
#   background-color: #dbf1d6;
#   color: #000000;
# }
# #T_e8a33_row9_col0 {
#   background-color: #eef8ea;
#   color: #000000;
# }
# #T_e8a33_row9_col4 {
#   background-color: #e8f6e4;
#   color: #000000;
# }
# #T_e8a33_row9_col8 {
#   background-color: #ceecc8;
#   color: #000000;
# }
# </style>
# <table id="T_e8a33" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Genre</th>
#       <th id="T_e8a33_level0_col0" class="col_heading level0 col0" >Action</th>
#       <th id="T_e8a33_level0_col1" class="col_heading level0 col1" >Adventure</th>
#       <th id="T_e8a33_level0_col2" class="col_heading level0 col2" >Fighting</th>
#       <th id="T_e8a33_level0_col3" class="col_heading level0 col3" >Misc</th>
#       <th id="T_e8a33_level0_col4" class="col_heading level0 col4" >Platform</th>
#       <th id="T_e8a33_level0_col5" class="col_heading level0 col5" >Puzzle</th>
#       <th id="T_e8a33_level0_col6" class="col_heading level0 col6" >Racing</th>
#       <th id="T_e8a33_level0_col7" class="col_heading level0 col7" >Role-Playing</th>
#       <th id="T_e8a33_level0_col8" class="col_heading level0 col8" >Shooter</th>
#       <th id="T_e8a33_level0_col9" class="col_heading level0 col9" >Simulation</th>
#       <th id="T_e8a33_level0_col10" class="col_heading level0 col10" >Sports</th>
#       <th id="T_e8a33_level0_col11" class="col_heading level0 col11" >Strategy</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Platform</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e8a33_level0_row0" class="row_heading level0 row0" >DS</th>
#       <td id="T_e8a33_row0_col0" class="data row0 col0" >112.700000

# %% [markdown]
# # Plotly

# %%
from plotly.offline import iplot
import plotly.graph_objs as go

data = []

for genre in df.Genre.unique():
    data.append(
        go.Box(y=df[df.Genre==genre].Critic_Score,
               name=genre)
    )
iplot(data)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="44cf3855-1d45-4146-8e69-0264592bed5a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("44cf3855-1d45-4146-8e69-0264592bed5a")) {                    Plotly.newPlot(                        "44cf3855-1d45-4146-8e69-0264592bed5a",                        [{"name":"Sports","y":[76.0,80.0,80.0,80.0,82.0,null,85.0,null,null,86.0,73.0,82.0,94.0,null,89.0,92.0,88.0,98.0,null,91.0,84.0,97.0,86.0,null,84.0,80.0,null,95.0,null,null,null,81.0,90.0,87.0,91.0,76.0,null,81.0,94.0,82.0,91.0,88.0,84.0,null,88.0,84.0,83.0,null,83.0,94.0,null,null,87.0,88.0,93.0,null,93.0,67.0,85.0,81.0,85.0,null,null,89.0,null,78.0,84.0,84.0,80.0,90.0,90.0,90.0,84.0,79.0,87.0,78.0,83.0,83.0,87.0,50.0,null,90.0,83.0,84.0,null,77.0,83.0,85.0,83.0,42.0,85.0,86.0,66.0,null,null,null,78.0,82.0,null,79.0,80.0,null,81.0,82.0,null,null,62.0,null,90.0,null,null,84.0,null,64.0,null,null,null,86.0,null,80.0,81.0,null,90.0,87.0,69.0,85.0,null,88.0,null,76.0,86.0,70.0,87.0,80.0,null,null,null,82.0,81.0,null,92.0,82.0,91.0,null,87.0,null,null,67.0,93.0,90.0,87.0,94.0,44.0,93.0,78.0,83.0,83.0,88.0,null,92.0,89.0,null,88.0,null,77.0,null,76.0,69.0,83.0,74.0,null,90.0,null,80.0,38.0,69.0,87.0,82.0,null,81.0,null,38.0,null,null,84.0,null,91.0,67.0,null,82.0,null,null,76.0,null,null,85.0,88.0,91.0,null,59.0,null,80.0,null,81.0,null,88.0,null,81.0,null,79.0,84.0,82.0,null,90.0,null,null,93.0,73.0,null,63.0,66.0,null,84.0,85.0,30.0,79.0,68.0,85.0,null,null,86.0,null,52.0,76.0,83.0,82.0,80.0,null,89.0,73.0,null,null,null,92.0,68.0,83.0,null,null,null,null,95.0,57.0,null,77.0,88.0,86.0,null,83.0,62.0,74.0,81.0,80.0,null,86.0,null,75.0,null,74.0,77.0,97.0,92.0,84.0,null,null,null,73.0,null,null,null,76.0,88.0,70.0,null,89.0,null,null,71.0,null,89.0,82.0,70.0,80.0,81.0,82.0,65.0,72.0,90.0,83.0,null,null,null,null,null,73.0,null,79.0,82.0,80.0,75.0,null,82.0,87.0,null,81.0,85.0,81.0,85.0,85.0,69.0,63.0,null,null,null,86.0,83.0,47.0,null,null,83.0,79.0,79.0,90.0,83.0,86.0,80.0,null,null,87.0,null,null,78.0,null,76.0,86.0,81.0,null,80.0,78.0,70.0,74.0,null,85.0,68.0,76.0,68.0,83.0,77.0,85.0,null,80.0,null,80.0,86.0,76.0,null,null,69.0,null,65.0,null,81.0,null,null,null,83.0,81.0,88.0,null,null,72.0,85.0,83.0,84.0,null,86.0,77.0,82.0,78.0,null,82.0,78.0,77.0,91.0,83.0,78.0,null,60.0,78.0,73.0,80.0,null,49.0,72.0,null,null,74.0,null,null,87.0,null,83.0,82.0,55.0,81.0,null,81.0,null,null,70.0,81.0,69.0,null,null,94.0,null,null,81.0,null,82.0,83.0,75.0,76.0,65.0,74.0,87.0,null,null,null,79.0,88.0,79.0,64.0,68.0,79.0,79.0,83.0,77.0,90.0,75.0,91.0,92.0,86.0,75.0,68.0,77.0,83.0,82.0,89.0,81.0,90.0,null,63.0,86.0,null,85.0,40.0,null,null,82.0,89.0,89.0,82.0,80.0,null,null,null,null,81.0,65.0,61.0,null,74.0,null,88.0,83.0,null,null,63.0,null,82.0,84.0,80.0,50.0,79.0,85.0,null,84.0,78.0,73.0,88.0,82.0,88.0,78.0,null,76.0,77.0,null,82.0,89.0,48.0,null,null,80.0,73.0,82.0,72.0,46.0,70.0,79.0,64.0,76.0,89.0,null,null,86.0,60.0,72.0,null,69.0,60.0,71.0,null,null,44.0,null,70.0,null,88.0,73.0,90.0,null,72.0,null,73.0,74.0,null,null,81.0,90.0,null,84.0,null,null,null,86.0,null,79.0,91.0,78.0,null,70.0,null,null,90.0,null,85.0,null,86.0,null,88.0,null,null,56.0,77.0,66.0,78.0,63.0,55.0,77.0,null,null,68.0,72.0,91.0,81.0,null,88.0,null,null,null,null,76.0,93.0,81.0,null,null,80.0,null,null,80.0,75.0,null,null,84.0,81.0,87.0,null,89.0,80.0,81.0,88.0,46.0,78.0,78.0,78.0,78.0,null,null,63.0,null,null,81.0,79.0,73.0,90.0,76.0,75.0,null,78.0,null,80.0,90.0,null,81.0,null,null,94.0,null,null,64.0,76.0,null,85.0,82.0,76.0,71.0,null,82.0,77.0,null,88.0,81.0,59.0,null,68.0,null,null,80.0,82.0,null,null,81.0,70.0,null,81.0,null,null,null,null,84.0,null,78.0,80.0,78.0,null,null,null,null,null,80.0,81.0,72.0,null,69.0,null,56.0,n ...

# %% [markdown]
# ## Дополниельные материалы
# 1. Документация Matplotlib https://matplotlib.org/contents.html
# 2. Документация Seaborn https://seaborn.pydata.org/tutorial.html
# 3. EDA, первичный визуальный анализ https://youtu.be/uJpDzHGUamg
# 4. Код. EDA, первичный визуальный анализ https://youtu.be/28XZf0Fv9-0
# 5. https://www.python-graph-gallery.com/
